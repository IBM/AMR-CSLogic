# %% [markdown]
# # test 1
# This code comes from amr_verbnet_semantics/test/test_ground_amr.py

# %%
from amr_verbnet_semantics.core.amr_verbnet_enhance import ground_amr

sample_ret = {'coreference': [], 'sentence_parses': [{'text': 'The dresser is made out of maple carefully finished with Danish oil.', 'amr': '# ::tok The dresser is made out of maple carefully finished with Danish oil . <ROOT>\n# ::node\t1\tdresser\t1-2\n# ::node\t2\tmake-01\t3-4\n# ::node\t3\tmaple\t6-7\n# ::node\t4\tcareful\t7-8\n# ::node\t5\tfinish-01\t8-9\n# ::node\t6\tcountry\t10-11\n# ::node\t8\toil\t11-12\n# ::node\t9\t"Denmark"\t10-11\n# ::node\t11\tname\t10-11\n# ::root\t2\tmake-01\n# ::edge\tmake-01\tARG1\tdresser\t2\t1\t\n# ::edge\tmake-01\tARG2\tmaple\t2\t3\t\n# ::edge\tfinish-01\tmanner\tcareful\t5\t4\t\n# ::edge\tmaple\tARG1-of\tfinish-01\t3\t5\t\n# ::edge\toil\tmod\tcountry\t8\t6\t\n# ::edge\tfinish-01\tARG2\toil\t5\t8\t\n# ::edge\tcountry\tname\tname\t6\t11\t\n# ::edge\tname\top1\t"Denmark"\t11\t9\t\n# ::short\t{1: \'d\', 2: \'m\', 3: \'m2\', 4: \'c\', 5: \'f\', 6: \'c2\', 8: \'o\', 9: \'x0\', 11: \'n\'}\t\n(m / make-01\n      :ARG1 (d / dresser)\n      :ARG2 (m2 / maple\n            :ARG1-of (f / finish-01\n                  :ARG2 (o / oil\n                        :mod (c2 / country\n                              :name (n / name\n                                    :op1 "Denmark")))\n                  :manner (c / careful))))\n\n', 'pb_vn_mappings': {'make.01': [{'mapping': 'build-26.1-1', 'source': 'verbnet3.4'}], 'finish.01': [{'mapping': 'stop-55.4-1-1', 'source': 'verbnet3.4'}]}, 'role_mappings': {'make.01': {':ARG0': [{'vncls': '26.1-1', 'vntheta': 'agent', 'description': 'creator'}], ':ARG1': [{'vncls': '26.1-1', 'vntheta': 'product', 'description': 'creation'}], ':ARG2': [{'vncls': '26.1-1', 'vntheta': 'material', 'description': 'created-from, thing changed'}], ':ARG3': [{'vncls': '26.1-1', 'vntheta': 'beneficiary', 'description': 'benefactive'}]}, 'finish.01': {':ARG0': [{'vncls': '55.4-1', 'vntheta': 'agent', 'description': 'Intentional agent'}], ':ARG1': [{'vncls': '55.4-1', 'vntheta': 'theme', 'description': 'Thing finishing'}]}}, 'amr_cal': [{'predicate': 'make-01', 'arguments': ['m'], 'is_negative': False}, {'predicate': 'dresser', 'arguments': ['d'], 'is_negative': False}, {'predicate': 'maple', 'arguments': ['m2'], 'is_negative': False}, {'predicate': 'finish-01', 'arguments': ['f'], 'is_negative': False}, {'predicate': 'oil', 'arguments': ['o'], 'is_negative': False}, {'predicate': 'country', 'arguments': ['c2'], 'is_negative': False}, {'predicate': 'name', 'arguments': ['n'], 'is_negative': False}, {'predicate': 'careful', 'arguments': ['c'], 'is_negative': False}, {'predicate': 'make-01.arg1', 'arguments': ['m', 'd'], 'is_negative': False}, {'predicate': 'make-01.arg2', 'arguments': ['m', 'm2'], 'is_negative': False}, {'predicate': 'finish-01.arg1', 'arguments': ['f', 'm2'], 'is_negative': False}, {'predicate': 'finish-01.arg2', 'arguments': ['f', 'o'], 'is_negative': False}, {'predicate': 'mod', 'arguments': ['o', 'c2'], 'is_negative': False}, {'predicate': 'name', 'arguments': ['c2', 'n'], 'is_negative': False}, {'predicate': 'manner', 'arguments': ['f', 'c'], 'is_negative': False}], 'sem_cal': {'make.01': {'build-26.1-1': [{'predicate': 'BE', 'arguments': ['Product', 'e1'], 'is_negative': True}, {'predicate': 'DO', 'arguments': ['e2', 'Agent'], 'is_negative': False}, {'predicate': 'BE', 'arguments': ['e3', 'Product'], 'is_negative': False}, {'predicate': 'MADE_OF', 'arguments': ['e3', 'Product', 'Material'], 'is_negative': False}, {'predicate': 'CAUSE', 'arguments': ['e2', 'e3'], 'is_negative': False}, {'predicate': 'COST', 'arguments': ['E', 'Product', 'Asset'], 'is_negative': False}]}, 'finish.01': {'stop-55.4-1-1': [{'predicate': 'DO', 'arguments': ['e1', 'Agent'], 'is_negative': False}, {'predicate': 'CAUSE', 'arguments': ['e2', 'e1'], 'is_negative': False}, {'predicate': 'END', 'arguments': ['E', 'Theme'], 'is_negative': False}]}}, 'unique_sem_cal': [{'make.01': [{'predicate': 'BE', 'arguments': ['Product', 'e1'], 'is_negative': True}, {'predicate': 'DO', 'arguments': ['e2', 'Agent'], 'is_negative': False}, {'predicate': 'BE', 'arguments': ['e3', 'Product'], 'is_negative': False}, {'predicate': 'MADE_OF', 'arguments': ['e3', 'Product', 'Material'], 'is_negative': False}, {'predicate': 'CAUSE', 'arguments': ['e2', 'e3'], 'is_negative': False}, {'predicate': 'COST', 'arguments': ['E', 'Product', 'Asset'], 'is_negative': False}], 'finish.01': [{'predicate': 'DO', 'arguments': ['e1', 'Agent'], 'is_negative': False}, {'predicate': 'CAUSE', 'arguments': ['e2', 'e1'], 'is_negative': False}, {'predicate': 'END', 'arguments': ['E', 'Theme'], 'is_negative': False}]}], 'grounded_stmt': {'make.01': {'build-26.1-1': [[{'predicate': 'BE', 'arguments': ['d', 'e1'], 'is_negative': True}, {'predicate': 'DO', 'arguments': ['e2', 'Agent'], 'is_negative': False}, {'predicate': 'BE', 'arguments': ['e3', 'd'], 'is_negative': False}, {'predicate': 'MADE_OF', 'arguments': ['e3', 'd', 'm2'], 'is_negative': False}, {'predicate': 'CAUSE', 'arguments': ['e2', 'e3'], 'is_negative': False}, {'predicate': 'COST', 'arguments': ['E', 'd', 'Asset'], 'is_negative': False}]]}, 'finish.01': {'stop-55.4-1-1': [[{'predicate': 'DO', 'arguments': ['e1', 'Agent'], 'is_negative': False}, {'predicate': 'CAUSE', 'arguments': ['e2', 'e1'], 'is_negative': False}, {'predicate': 'END', 'arguments': ['E', 'm2'], 'is_negative': False}]]}}, 'unique_grounded_stmt': [{'make.01': [[{'predicate': 'BE', 'arguments': ['d', 'e1'], 'is_negative': True}, {'predicate': 'DO', 'arguments': ['e2', 'Agent'], 'is_negative': False}, {'predicate': 'BE', 'arguments': ['e3', 'd'], 'is_negative': False}, {'predicate': 'MADE_OF', 'arguments': ['e3', 'd', 'm2'], 'is_negative': False}, {'predicate': 'CAUSE', 'arguments': ['e2', 'e3'], 'is_negative': False}, {'predicate': 'COST', 'arguments': ['E', 'd', 'Asset'], 'is_negative': False}]], 'finish.01': [[{'predicate': 'DO', 'arguments': ['e1', 'Agent'], 'is_negative': False}, {'predicate': 'CAUSE', 'arguments': ['e2', 'e1'], 'is_negative': False}, {'predicate': 'END', 'arguments': ['E', 'm2'], 'is_negative': False}]]}], 'amr_cal_str': '[make-01(m), dresser(d), maple(m2), finish-01(f), oil(o), country(c2), name(n), careful(c), make-01.arg1(m, d), make-01.arg2(m, m2), finish-01.arg1(f, m2), finish-01.arg2(f, o), mod(o, c2), name(c2, n), manner(f, c)]', 'sem_cal_str': "{'make.01': {'build-26.1-1': [NOT(BE(Product, e1)), DO(e2, Agent), BE(e3, Product), MADE_OF(e3, Product, Material), CAUSE(e2, e3), COST(E, Product, Asset)]}, 'finish.01': {'stop-55.4-1-1': [DO(e1, Agent), CAUSE(e2, e1), END(E, Theme)]}}", 'unique_sem_cal_str': "[{'make.01': [NOT(BE(Product, e1)), DO(e2, Agent), BE(e3, Product), MADE_OF(e3, Product, Material), CAUSE(e2, e3), COST(E, Product, Asset)], 'finish.01': [DO(e1, Agent), CAUSE(e2, e1), END(E, Theme)]}]", 'grounded_stmt_str': "{'make.01': {'build-26.1-1': [[NOT(BE(d, e1)), DO(e2, Agent), BE(e3, d), MADE_OF(e3, d, m2), CAUSE(e2, e3), COST(E, d, Asset)]]}, 'finish.01': {'stop-55.4-1-1': [[DO(e1, Agent), CAUSE(e2, e1), END(E, m2)]]}}", 'unique_grounded_stmt_str': "[{'make.01': [[NOT(BE(d, e1)), DO(e2, Agent), BE(e3, d), MADE_OF(e3, d, m2), CAUSE(e2, e3), COST(E, d, Asset)]], 'finish.01': [[DO(e1, Agent), CAUSE(e2, e1), END(E, m2)]]}]"}]}

amr = sample_ret['sentence_parses'][0]['amr']
r = ground_amr(amr, verbose=False)
print(r)
print('\ngrounded_stmt_str', r['grounded_stmt_str'])
# Out:
# {'pb_vn_mappings': {'make.01': [{'mapping': 'build-26.1-1', 'source': 'verbnet3.4'}], 'finish.01': [{'mapping': 'stop-55.4-1', 'source': 'verbnet3.4'}]}, 'role_mappings': {'make.01': {'ARG0': [{'vncls': '26.1-1', 'vntheta': 'agent', 'description': 'creator'}], 'ARG1': [{'vncls': '26.1-1', 'vntheta': 'product', 'description': 'creation'}], 'ARG2': [{'vncls': '26.1-1', 'vntheta': 'material', 'description': 'created-from, thing changed'}], 'ARG3': [{'vncls': '26.1-1', 'vntheta': 'beneficiary', 'description': 'benefactive'}]}, 'finish.01': {'ARG1': [{'vncls': '55.4-1', 'vntheta': 'theme', 'description': 'Thing finishing'}]}}, 'amr_cal': [{'predicate': 'make-01', 'arguments': ['m'], 'is_negative': False}, {'predicate': 'dresser', 'arguments': ['d'], 'is_negative': False}, {'predicate': 'maple', 'arguments': ['m2'], 'is_negative': False}, {'predicate': 'finish-01', 'arguments': ['f'], 'is_negative': False}, {'predicate': 'oil', 'arguments': ['o'], 'is_negative': False}, {'predicate': 'country', 'arguments': ['c2'], 'is_negative': False}, {'predicate': 'name', 'arguments': ['n'], 'is_negative': False}, {'predicate': 'careful', 'arguments': ['c'], 'is_negative': False}, {'predicate': 'make-01.arg1', 'arguments': ['m', 'd'], 'is_negative': False}, {'predicate': 'make-01.arg2', 'arguments': ['m', 'm2'], 'is_negative': False}, {'predicate': 'finish-01.arg1', 'arguments': ['f', 'm2'], 'is_negative': False}, {'predicate': 'finish-01.arg2', 'arguments': ['f', 'o'], 'is_negative': False}, {'predicate': 'mod', 'arguments': ['o', 'c2'], 'is_negative': False}, {'predicate': 'name', 'arguments': ['c2', 'n'], 'is_negative': False}, {'predicate': 'manner', 'arguments': ['f', 'c'], 'is_negative': False}], 'sem_cal': {'make.01': {'build-26.1-1': [{'predicate': 'BE', 'arguments': ['Product', 'e1'], 'is_negative': True}, {'predicate': 'DO', 'arguments': ['e2', 'Agent'], 'is_negative': False}, {'predicate': 'BE', 'arguments': ['e3', 'Product'], 'is_negative': False}, {'predicate': 'MADE_OF', 'arguments': ['e3', 'Product', 'Material'], 'is_negative': False}, {'predicate': 'CAUSE', 'arguments': ['e2', 'e3'], 'is_negative': False}, {'predicate': 'COST', 'arguments': ['E', 'Product', 'Asset'], 'is_negative': False}]}, 'finish.01': {'stop-55.4-1': [{'predicate': 'END', 'arguments': ['E', 'Theme'], 'is_negative': False}]}}, 'unique_sem_cal': [{'make.01': [{'predicate': 'BE', 'arguments': ['Product', 'e1'], 'is_negative': True}, {'predicate': 'DO', 'arguments': ['e2', 'Agent'], 'is_negative': False}, {'predicate': 'BE', 'arguments': ['e3', 'Product'], 'is_negative': False}, {'predicate': 'MADE_OF', 'arguments': ['e3', 'Product', 'Material'], 'is_negative': False}, {'predicate': 'CAUSE', 'arguments': ['e2', 'e3'], 'is_negative': False}, {'predicate': 'COST', 'arguments': ['E', 'Product', 'Asset'], 'is_negative': False}], 'finish.01': [{'predicate': 'END', 'arguments': ['E', 'Theme'], 'is_negative': False}]}], 'grounded_stmt': {'make.01': {'build-26.1-1': [[{'predicate': 'BE', 'arguments': ['d', 'e1'], 'is_negative': True}, {'predicate': 'DO', 'arguments': ['e2', 'Agent'], 'is_negative': False}, {'predicate': 'BE', 'arguments': ['e3', 'd'], 'is_negative': False}, {'predicate': 'MADE_OF', 'arguments': ['e3', 'd', 'm2'], 'is_negative': False}, {'predicate': 'CAUSE', 'arguments': ['e2', 'e3'], 'is_negative': False}, {'predicate': 'COST', 'arguments': ['E', 'd', 'Asset'], 'is_negative': False}]]}, 'finish.01': {'stop-55.4-1': [[{'predicate': 'END', 'arguments': ['E', 'm2'], 'is_negative': False}]]}}, 'unique_grounded_stmt': [{'make.01': [[{'predicate': 'BE', 'arguments': ['d', 'e1'], 'is_negative': True}, {'predicate': 'DO', 'arguments': ['e2', 'Agent'], 'is_negative': False}, {'predicate': 'BE', 'arguments': ['e3', 'd'], 'is_negative': False}, {'predicate': 'MADE_OF', 'arguments': ['e3', 'd', 'm2'], 'is_negative': False}, {'predicate': 'CAUSE', 'arguments': ['e2', 'e3'], 'is_negative': False}, {'predicate': 'COST', 'arguments': ['E', 'd', 'Asset'], 'is_negative':  ...
#
# grounded_stmt_str {'make.01': {'build-26.1-1': [[NOT(BE(d, e1)), DO(e2, Agent), BE(e3, d), MADE_OF(e3, d, m2), CAUSE(e2, e3), COST(E, d, Asset)]]}, 'finish.01': {'stop-55.4-1': [[END(E, m2)]]}}

# %% [markdown]
# # test 2
# This code comes from amr_verbnet_semantics/test/test_ground_text_to_verbnet.py
#
# be-located-at-91 has no semantic role mappings in propbank.

# %%
import time

from amr_verbnet_semantics.core.amr_verbnet_enhance import ground_text_to_verbnet

start = time.time()

text="You're in a corridor. You can see a shoe cabinet. The shoe cabinet contains a top hat. You lean against the wall, inadvertently pressing a secret button. The wall opens up to reveal a coat hanger. The coat hanger is normal. But the thing is empty. You can make out a hat rack. Looks like someone's already been here and taken everything off it, though. Hm. Oh well You hear a noise behind you and spin around, but you can't see anything other than an umbrella stand. The umbrella stand is usual. But the thing is empty, unfortunately. Hm. Oh well You hear a noise behind you and spin around, but you can't see anything other than a key holder! The key holder is ordinary. But the thing is empty. It would have been so cool if there was stuff on the key holder."
ret = ground_text_to_verbnet(text, use_coreference=True)
print(f"ret: {ret}")
print(f"grounded_stmt of last sentence: {ret['sentence_parses'][-1]['grounded_stmt']}")

print(f'finish with {time.time()-start:.3f} seconds')
# Out:
# Loading StanfordCoreNLP models ...
# Models created ...
#
# amr:
#
# # ::tok You 're in a corridor . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	be-located-at-91	2-3
# # ::node	3	corridor	4-5
# # ::root	2	be-located-at-91
# # ::edge	be-located-at-91	ARG1	you	2	1
# # ::edge	be-located-at-91	ARG2	corridor	2	3
# # ::short	{1: 'y', 2: 'b', 3: 'c'}
# (b / be-located-at-91
#       :ARG1 (y / you)
#       :ARG2 (c / corridor))
#
#
#
# amr:
#
# # ::tok You 're in a corridor . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	be-located-at-91	2-3
# # ::node	3	corridor	4-5
# # ::root	2	be-located-at-91
# # ::edge	be-located-at-91	ARG1	you	2	1
# # ::edge	be-located-at-91	ARG2	corridor	2	3
# # ::short	{1: 'y', 2: 'b', 3: 'c'}
# (b / be-located-at-91
#       :ARG1 (y / you)
#       :ARG2 (c / corridor))
#
#
#
# amr:
#
# # ::tok You 're in a corridor . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	be-located-at-91	2-3
# # ::node	3	corridor	4-5
# # ::root	2	be-located-at-91
# # ::edge	be-located-at-91	ARG1	you	2	1
# # ::edge	be-located-at-91	ARG2	corridor	2	3
# # ::short	{1: 'y', 2: 'b', 3: 'c'}
# (b / be-located-at-91
#       :ARG1 (y / you)
#       :ARG2 (c / corridor))
#
#
#
# amr:
#
# # ::tok You 're in a corridor . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	be-located-at-91	2-3
# # ::node	3	corridor	4-5
# # ::root	2	be-located-at-91
# # ::edge	be-located-at-91	ARG1	you	2	1
# # ::edge	be-located-at-91	ARG2	corridor	2	3
# # ::short	{1: 'y', 2: 'b', 3: 'c'}
# (b / be-located-at-91
#       :ARG1 (y / you)
#       :ARG2 (c / corridor))
#
#
#
# amr:
#
# # ::tok You 're in a corridor . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	be-located-at-91	2-3
# # ::node	3	corridor	4-5
# # ::root	2	be-located-at-91
# # ::edge	be-located-at-91	ARG1	you	2	1
# # ::edge	be-located-at-91	ARG2	corridor	2	3
# # ::short	{1: 'y', 2: 'b', 3: 'c'}
# (b / be-located-at-91
#       :ARG1 (y / you)
#       :ARG2 (c / corridor))
#
#
#
# amr:
#
# # ::tok You 're in a corridor . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	be-located-at-91	2-3
# # ::node	3	corridor	4-5
# # ::root	2	be-located-at-91
# # ::edge	be-located-at-91	ARG1	you	2	1
# # ::edge	be-located-at-91	ARG2	corridor	2	3
# # ::short	{1: 'y', 2: 'b', 3: 'c'}
# (b / be-located-at-91
#       :ARG1 (y / you)
#       :ARG2 (c / corridor))
#
#
#
# amr:
#
# # ::tok You 're in a corridor . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	be-located-at-91	2-3
# # ::node	3	corridor	4-5
# # ::root	2	be-located-at-91
# # ::edge	be-located-at-91	ARG1	you	2	1
# # ::edge	be-located-at-91	ARG2	corridor	2	3
# # ::short	{1: 'y', 2: 'b', 3: 'c'}
# (b / be-located-at-91
#       :ARG1 (y / you)
#       :ARG2 (c / corridor))
#
#
#
# amr:
#
# # ::tok You 're in a corridor . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	be-located-at-91	2-3
# # ::node	3	corridor	4-5
# # ::root	2	be-located-at-91
# # ::edge	be-located-at-91	ARG1	you	2	1
# # ::edge	be-located-at-91	ARG2	corridor	2	3
# # ::short	{1: 'y', 2: 'b', 3: 'c'}
# (b / be-located-at-91
#       :ARG1 (y / you)
#       :ARG2 (c / corridor))
#
#
#
# amr:
#
# # ::tok You 're in a corridor . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	be-located-at-91	2-3
# # ::node	3	corridor	4-5
# # ::root	2	be-located-at-91
# # ::edge	be-located-at-91	ARG1	you	2	1
# # ::edge	be-located-at-91	ARG2	corridor	2	3
# # ::short	{1: 'y', 2: 'b', 3: 'c'}
# (b / be-located-at-91
#       :ARG1 (y / you)
#       :ARG2 (c / corridor))
#
#
#
# amr:
#
# # ::tok You 're in a corridor . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	be-located-at-91	2-3
# # ::node	3	corridor	4-5
# # ::root	2	be-located-at-91
# # ::edge	be-located-at-91	ARG1	you	2	1
# # ::edge	be-located-at-91	ARG2	corridor	2	3
# # ::short	{1: 'y', 2: 'b', 3: 'c'}
# (b / be-located-at-91
#       :ARG1 (y / you)
#       :ARG2 (c / corridor))
#
#
#
# amr:
#
# # ::tok You 're in a corridor . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	be-located-at-91	2-3
# # ::node	3	corridor	4-5
# # ::root	2	be-located-at-91
# # ::edge	be-located-at-91	ARG1	you	2	1
# # ::edge	be-located-at-91	ARG2	corridor	2	3
# # ::short	{1: 'y', 2: 'b', 3: 'c'}
# (b / be-located-at-91
#       :ARG1 (y / you)
#       :ARG2 (c / corridor))
#
#
#
# amr:
#
# # ::tok You 're in a corridor . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	be-located-at-91	2-3
# # ::node	3	corridor	4-5
# # ::root	2	be-located-at-91
# # ::edge	be-located-at-91	ARG1	you	2	1
# # ::edge	be-located-at-91	ARG2	corridor	2	3
# # ::short	{1: 'y', 2: 'b', 3: 'c'}
# (b / be-located-at-91
#       :ARG1 (y / you)
#       :ARG2 (c / corridor))
#
#
#
# amr:
#
# # ::tok You 're in a corridor . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	be-located-at-91	2-3
# # ::node	3	corridor	4-5
# # ::root	2	be-located-at-91
# # ::edge	be-located-at-91	ARG1	you	2	1
# # ::edge	be-located-at-91	ARG2	corridor	2	3
# # ::short	{1: 'y', 2: 'b', 3: 'c'}
# (b / be-located-at-91
#       :ARG1 (y / you)
#       :ARG2 (c / corridor))
#
#
#
# amr:
#
# # ::tok You 're in a corridor . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	be-located-at-91	2-3
# # ::node	3	corridor	4-5
# # ::root	2	be-located-at-91
# # ::edge	be-located-at-91	ARG1	you	2	1
# # ::edge	be-located-at-91	ARG2	corridor	2	3
# # ::short	{1: 'y', 2: 'b', 3: 'c'}
# (b / be-located-at-91
#       :ARG1 (y / you)
#       :ARG2 (c / corridor))
#
#
#
# amr:
#
# # ::tok You 're in a corridor . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	be-located-at-91	2-3
# # ::node	3	corridor	4-5
# # ::root	2	be-located-at-91
# # ::edge	be-located-at-91	ARG1	you	2	1
# # ::edge	be-located-at-91	ARG2	corridor	2	3
# # ::short	{1: 'y', 2: 'b', 3: 'c'}
# (b / be-located-at-91
#       :ARG1 (y / you)
#       :ARG2 (c / corridor))
#
#
#
# amr:
#
# # ::tok You 're in a corridor . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	be-located-at-91	2-3
# # ::node	3	corridor	4-5
# # ::root	2	be-located-at-91
# # ::edge	be-located-at-91	ARG1	you	2	1
# # ::edge	be-located-at-91	ARG2	corridor	2	3
# # ::short	{1: 'y', 2: 'b', 3: 'c'}
# (b / be-located-at-91
#       :ARG1 (y / you)
#       :ARG2 (c / corridor))
#
#
#
# amr:
#
# # ::tok You 're in a corridor . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	be-located-at-91	2-3
# # ::node	3	corridor	4-5
# # ::root	2	be-located-at-91
# # ::edge	be-located-at-91	ARG1	you	2	1
# # ::edge	be-located-at-91	ARG2	corridor	2	3
# # ::short	{1: 'y', 2: 'b', 3: 'c'}
# (b / be-located-at-91
#       :ARG1 (y / you)
#       :ARG2 (c / corridor))
#
#
#
# amr:
#
# # ::tok You 're in a corridor . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	be-located-at-91	2-3
# # ::node	3	corridor	4-5
# # ::root	2	be-located-at-91
# # ::edge	be-located-at-91	ARG1	you	2	1
# # ::edge	be-located-at-91	ARG2	corridor	2	3
# # ::short	{1: 'y', 2: 'b', 3: 'c'}
# (b / be-located-at-91
#       :ARG1 (y / you)
#       :ARG2 (c / corridor))
#
#
# ret: {'coreference': [[(11, 5, 9, 'a noise behind you'), (15, 5, 9, 'a noise behind you')], [(7, 2, 4, 'the thing'), (9, 12, 13, 'it'), (13, 2, 4, 'the thing'), (17, 2, 4, 'the thing'), (18, 1, 2, 'It')], [(2, 4, 7, 'a shoe cabinet'), (3, 1, 4, 'The shoe cabinet')], [(15, 21, 24, 'a key holder'), (16, 1, 4, 'The key holder'), (18, 12, 15, 'the key holder')], [(4, 4, 6, 'the wall'), (5, 1, 3, 'The wall')], [(11, 21, 24, 'an umbrella stand'), (12, 1, 4, 'The umbrella stand')], [(5, 7, 10, 'a coat hanger'), (6, 1, 4, 'The coat hanger')], [(1, 1, 2, 'You'), (2, 1, 2, 'You'), (4, 1, 2, 'You'), (8, 1, 2, 'You'), (11, 3, 4, 'You'), (11, 8, 9, 'you'), (11, 14, 15, 'you'), (15, 3, 4, 'You'), (15, 8, 9, 'you'), (15, 14, 15, 'you')]], 'sentence_parses': [{'text': "You're in a corridor.", 'amr': "# ::tok You 're in a corridor . <ROOT>\n# ::node\t1\tyou\t0-1\n# ::node\t2\tbe-located-at-91\t2-3\n# ::node\t3\tcorridor\t4-5\n# ::root\t2\tbe-located-at-91\n# ::edge\tbe-located-at-91\tARG1\tyou\t2\t1\t\n# ::edge\tbe-located-at-91\tARG2\tcorridor\t2\t3\t\n# ::short\t{1: 'y', 2: 'b', 3: 'c'}\t\n(b / be-located-at-91\n      :ARG1 (y / you)\n      :ARG2 (c / corridor))\n\n", 'pb_vn_mappings': {}, 'role_mappings': {'be-located-at.91': {}}, 'amr_cal': [{'predicate': 'be-located-at-91', 'arguments': ['b'], 'is_negative': False}, {'predicate': 'you', 'arguments': ['y'], 'is_negative': False}, {'predicate': 'corridor', 'arguments': ['c'], 'is_negative': False}, {'predicate': 'be-located-at-91.arg1', 'arguments': ['b', 'y'], 'is_negative': False}, {'predicate': 'be-located-at-91.arg2', 'arguments': ['b', 'c'], 'is_negative': False}], 'sem_cal': {}, 'unique_sem_cal': [{}], 'grounded_stmt': {}, 'unique_grounded_stmt': [{}], 'amr_cal_str': '[be-located-at-91(b), you(y), corridor(c), be-located-at-91.arg1(b, y), be-located-at-91.arg2(b, c)]', 'sem_cal_str': '{}', 'unique_sem_cal_str': '[{}]', 'grounded_stmt_str': '{}', 'unique_grounded_stmt_str': '[{}]'}, {'text': 'You can see a shoe cabinet.', 'amr': "# ::tok You 're in a corridor . <ROOT>\n# ::node\t1\tyou\t0-1\n# ::node\t2\tbe-located-at-91\t2-3\n# ::node\t3\tcorridor\t4-5\n# ::root\t2\tbe-located-at-91\n# ::edge\tbe-located-at-91\tARG1\tyou\t2\t1\t\n# ::edge\tbe-located-at-91\tARG2\tcorridor\t2\t3\t\n# ::short\t{1: 'y', 2: 'b', 3: 'c'}\t\n(b / be-located-at-91\n      :ARG1 (y / you)\n      :ARG2 (c / corridor))\n\n", 'pb_vn_mappings': {}, 'role_mappings': {'be-located-at.91': {}}, 'amr_cal': [{'predicate': 'be-located-at-91', 'arguments': ['b'], 'is_negative': False}, {'predicate': 'you', 'arguments': ['y'], 'is_negative': False}, {'predicate': 'corridor', 'arguments': ['c'], 'is_negative': False}, {'predicate': 'be-located-at-91.arg1', 'arguments': ['b', 'y'], 'is_negative': False}, {'predicate': 'be-located-at-91.arg2', 'arguments': ['b', 'c'], 'is_negative': False}], 'sem_cal': {}, 'unique_sem_cal': [{}], 'grounded_stmt': {}, 'unique_grounded_stmt': [{}], 'amr_cal_str': '[be-located-at-91(b), you(y), corridor(c), be-located-at-91.arg1(b, y), be-located-at-91.arg2(b, c)]', 'sem_cal_str': '{}', 'unique_sem_cal_str': '[{}]', 'grounded_stmt_str': '{}', 'unique_grounded_stmt_str': '[{}]'}, {'text': 'The shoe cabinet contains a top hat.', 'amr': "# ::tok You 're in a corridor . <ROOT>\n# ::node\t1\tyou\t0-1\n# ::node\t2\tbe-located-at-91\t2-3\n# ::node\t3\tcorridor\t4-5\n# ::root\t2\tbe-located-at-91\n# ::edge\tbe-located-at-91\tARG1\tyou\t2\t1\t\n# ::edge\tbe-located-at-91\tARG2\tcorridor\t2\t3\t\n# ::short\t{1: 'y', 2: 'b', 3: 'c'}\t\n(b / be-located-at-91\n      :ARG1 (y / you)\n      :ARG2 (c / corridor))\n\n", 'pb_vn_mappings': {}, 'role_mappings': {'be-located-at.91': {}}, 'amr_cal': [{'predicate': 'be-located-at-91', 'arguments': ['b'], 'is_negative': False}, {'predicate': 'you', 'arguments': ['y'], 'is_negative': False}, {'predicate': 'corridor', 'arguments': ['c'], 'is_negative': False}, {'predicate': 'be-located-at-91.arg1', 'arguments': ['b', 'y'], 'is_negative': False}, {'predicate': 'be-located ...
# grounded_stmt of last sentence: {}
# finish with 44.040 seconds

# %% [markdown]
# # test 3
# This code comes from amr_verbnet_semantics/test/test_query_semantics.py

# %%
from amr_verbnet_semantics.service.verbnet import query_semantics


verbnet_version = 'verbnet3.4'
verbnet_id = 'spray-9.7-2'
semantics = query_semantics(verbnet_id, verbnet_version)
print(semantics)
print()

verbnet_id = 'build-26.1-1'
semantics = query_semantics(verbnet_id, verbnet_version)
print(semantics)
print()

verbnet_id = 'stop-55.4-1-1'
semantics = query_semantics(verbnet_id, verbnet_version)
print(semantics)
print()
# Out:
# {}
#
# {('Asset', 'Agent', 'Product'): [{'predicate_value': 'be', 'arguments': [{'type': 'Event', 'value': 'e1'}, {'type': 'ThemRole', 'value': 'Product'}], 'is_negative': True}, {'predicate_value': 'do', 'arguments': [{'type': 'Event', 'value': 'e2'}, {'type': 'ThemRole', 'value': 'Agent'}], 'is_negative': False}, {'predicate_value': 'be', 'arguments': [{'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Product'}], 'is_negative': False}, {'predicate_value': 'made_of', 'arguments': [{'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Product'}, {'type': 'ThemRole', 'value': '?Material'}], 'is_negative': False}, {'predicate_value': 'cause', 'arguments': [{'type': 'Event', 'value': 'e2'}, {'type': 'Event', 'value': 'e3'}], 'is_negative': False}, {'predicate_value': 'cost', 'arguments': [{'type': 'Event', 'value': 'E'}, {'type': 'ThemRole', 'value': 'Product'}, {'type': 'ThemRole', 'value': 'Asset'}], 'is_negative': False}], ('Asset', 'Agent', 'Beneficiary', 'Product'): [{'predicate_value': 'be', 'arguments': [{'type': 'ThemRole', 'value': 'Product'}, {'type': 'Event', 'value': 'e1'}], 'is_negative': True}, {'predicate_value': 'do', 'arguments': [{'type': 'Event', 'value': 'e2'}, {'type': 'ThemRole', 'value': 'Agent'}], 'is_negative': False}, {'predicate_value': 'be', 'arguments': [{'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Product'}], 'is_negative': False}, {'predicate_value': 'made_of', 'arguments': [{'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Product'}, {'type': 'ThemRole', 'value': '?Material'}], 'is_negative': False}, {'predicate_value': 'cause', 'arguments': [{'type': 'Event', 'value': 'e2'}, {'type': 'Event', 'value': 'e3'}], 'is_negative': False}, {'predicate_value': 'benefit', 'arguments': [{'type': 'Event', 'value': 'E'}, {'type': 'ThemRole', 'value': 'Beneficiary'}], 'is_negative': False}, {'predicate_value': 'cost', 'arguments': [{'type': 'Event', 'value': 'E'}, {'type': 'ThemRole', 'value': 'Product'}, {'type': 'ThemRole', 'value': 'Asset'}], 'is_negative': False}], ('Material', 'Agent', 'Asset', 'Product'): [{'predicate_value': 'be', 'arguments': [{'type': 'ThemRole', 'value': 'Product'}, {'type': 'Event', 'value': 'e1'}], 'is_negative': True}, {'predicate_value': 'do', 'arguments': [{'type': 'Event', 'value': 'e2'}, {'type': 'ThemRole', 'value': 'Agent'}], 'is_negative': False}, {'predicate_value': 'be', 'arguments': [{'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Product'}], 'is_negative': False}, {'predicate_value': 'made_of', 'arguments': [{'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Product'}, {'type': 'ThemRole', 'value': 'Material'}], 'is_negative': False}, {'predicate_value': 'cause', 'arguments': [{'type': 'Event', 'value': 'e2'}, {'type': 'Event', 'value': 'e3'}], 'is_negative': False}, {'predicate_value': 'cost', 'arguments': [{'type': 'Event', 'value': 'E'}, {'type': 'ThemRole', 'value': 'Product'}, {'type': 'ThemRole', 'value': 'Asset'}], 'is_negative': False}], ('Asset', 'Agent', 'Material', 'Beneficiary', 'Product'): [{'predicate_value': 'be', 'arguments': [{'type': 'ThemRole', 'value': 'Product'}, {'type': 'Event', 'value': 'e1'}], 'is_negative': True}, {'predicate_value': 'do', 'arguments': [{'type': 'ThemRole', 'value': 'Agent'}, {'type': 'Event', 'value': 'e2'}], 'is_negative': False}, {'predicate_value': 'be', 'arguments': [{'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Product'}], 'is_negative': False}, {'predicate_value': 'made_of', 'arguments': [{'type': 'ThemRole', 'value': 'Material'}, {'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Product'}], 'is_negative': False}, {'predicate_value': 'cause', 'arguments': [{'type': 'Event', 'value': 'e2'}, {'type': 'Event', 'value': 'e3'}], 'is_negative': False}, {'predicate_value': 'benefit', 'arguments': [{'type': 'ThemRole', 'value': 'Beneficiary'}, {'type': 'Event', 'value': 'E'}], 'is_negative': False}, {'predicate_v ...
#
# {('Theme', 'Agent'): [{'predicate_value': 'do', 'arguments': [{'type': 'Event', 'value': 'e1'}, {'type': 'ThemRole', 'value': 'Agent'}], 'is_negative': False}, {'predicate_value': 'cause', 'arguments': [{'type': 'Event', 'value': 'e1'}, {'type': 'Event', 'value': 'e2'}], 'is_negative': False}, {'predicate_value': 'end', 'arguments': [{'type': 'Event', 'value': 'E'}, {'type': 'ThemRole', 'value': 'Theme'}], 'is_negative': False}]}

# %% [markdown]
# # test 4
# This code comes from amr_verbnet_semantics/test/test_verbnet.py

# %%
from nltk.corpus.reader import VerbnetCorpusReader
from nltk.corpus.util import LazyCorpusLoader

verbnet = LazyCorpusLoader("verbnet3.4", VerbnetCorpusReader, r"(?!\.).*\.xml")
print(verbnet.frames("escape-51.1-1"))
try:
    print(verbnet.frames("escape-51.1-2"))
except Exception as e:
    print(e)

print(verbnet.frames("leave-51.2"))
print(verbnet.subclasses("escape-51.1-1"))
# Out:
# [{'example': '\nThe prisoners advanced.\n', 'description': {'primary': 'NP V', 'secondary': 'Basic Intransitive'}, 'syntax': [{'pos_tag': 'NP', 'modifiers': {'value': 'Theme', 'selrestrs': [], 'synrestrs': []}}, {'pos_tag': 'VERB', 'modifiers': {'value': '', 'selrestrs': [], 'synrestrs': []}}], 'semantics': [{'predicate_value': 'has_location', 'arguments': [{'type': 'Event', 'value': 'e1'}, {'type': 'ThemRole', 'value': 'Theme'}, {'type': 'ThemRole', 'value': '?Initial_Location'}]}, {'predicate_value': 'motion', 'arguments': [{'type': 'Event', 'value': 'ë2'}, {'type': 'ThemRole', 'value': 'Theme'}, {'type': 'ThemRole', 'value': '?Trajectory'}]}, {'predicate_value': 'has_location', 'arguments': [{'type': 'Event', 'value': 'e2'}, {'type': 'ThemRole', 'value': 'Theme'}, {'type': 'ThemRole', 'value': '?Initial_Location'}]}, {'predicate_value': 'has_location', 'arguments': [{'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Theme'}, {'type': 'ThemRole', 'value': '?Destination'}]}]}, {'example': '\nHe came from France.\n', 'description': {'primary': 'NP V PP.initial_location', 'secondary': 'PP; initial_loc-PP'}, 'syntax': [{'pos_tag': 'NP', 'modifiers': {'value': 'Theme', 'selrestrs': [], 'synrestrs': []}}, {'pos_tag': 'VERB', 'modifiers': {'value': '', 'selrestrs': [], 'synrestrs': []}}, {'pos_tag': 'PREP', 'modifiers': {'value': '', 'selrestrs': [{'value': '+', 'type': 'path'}], 'synrestrs': []}}, {'pos_tag': 'NP', 'modifiers': {'value': 'Initial_Location', 'selrestrs': [], 'synrestrs': []}}], 'semantics': [{'predicate_value': 'has_location', 'arguments': [{'type': 'Event', 'value': 'e1'}, {'type': 'ThemRole', 'value': 'Theme'}, {'type': 'ThemRole', 'value': 'Initial_Location'}]}, {'predicate_value': 'motion', 'arguments': [{'type': 'Event', 'value': 'ë2'}, {'type': 'ThemRole', 'value': 'Theme'}, {'type': 'ThemRole', 'value': '?Trajectory'}]}, {'predicate_value': 'has_location', 'arguments': [{'type': 'Event', 'value': 'e2'}, {'type': 'ThemRole', 'value': 'Theme'}, {'type': 'ThemRole', 'value': 'Initial_Location'}]}, {'predicate_value': 'has_location', 'arguments': [{'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Theme'}, {'type': 'ThemRole', 'value': '?Destination'}]}]}]
# Unknown identifier escape-51.1-2
# [{'example': '\nHe deserted his post.\n', 'description': {'primary': 'NP V NP.initial_location', 'secondary': 'Transitive; locatum cannot be realized in a PP'}, 'syntax': [{'pos_tag': 'NP', 'modifiers': {'value': 'Theme', 'selrestrs': [], 'synrestrs': []}}, {'pos_tag': 'VERB', 'modifiers': {'value': '', 'selrestrs': [], 'synrestrs': []}}, {'pos_tag': 'NP', 'modifiers': {'value': 'Source', 'selrestrs': [], 'synrestrs': []}}], 'semantics': [{'predicate_value': 'has_location', 'arguments': [{'type': 'Event', 'value': 'e1'}, {'type': 'ThemRole', 'value': 'Theme'}, {'type': 'ThemRole', 'value': 'Source'}]}, {'predicate_value': 'motion', 'arguments': [{'type': 'Event', 'value': 'ë2'}, {'type': 'ThemRole', 'value': 'Theme'}, {'type': 'ThemRole', 'value': '?Trajectory'}]}, {'predicate_value': 'has_location', 'arguments': [{'type': 'Event', 'value': 'ë2'}, {'type': 'ThemRole', 'value': 'Theme'}, {'type': 'ThemRole', 'value': 'Source'}]}, {'predicate_value': 'has_location', 'arguments': [{'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Theme'}, {'type': 'ThemRole', 'value': '?Goal'}]}]}, {'example': '\nShe left her husband for another man.\n', 'description': {'primary': 'NP V NP.initial_location PP.destination', 'secondary': 'Transitive with PP-destination'}, 'syntax': [{'pos_tag': 'NP', 'modifiers': {'value': 'Theme', 'selrestrs': [], 'synrestrs': []}}, {'pos_tag': 'VERB', 'modifiers': {'value': '', 'selrestrs': [], 'synrestrs': []}}, {'pos_tag': 'NP', 'modifiers': {'value': 'Source', 'selrestrs': [], 'synrestrs': []}}, {'pos_tag': 'PREP', 'modifiers': {'value': '', 'selrestrs': [{'value': '+', 'type': 'path'}], 'synrestrs': []}}, {'pos_tag': 'NP', 'modifiers': {'value': 'Destination', 'selrestrs': [], 'synrestrs': []}}], 'semantics': [{'predicate_value': 'has_location', 'arguments': [{'type': 'Event', 'value': 'e1'}, {'type': 'ThemRole', 'value': 'Theme'}, {'type': 'ThemRole', 'value': 'Source'}]}, {'predicate_value': 'motion', 'arguments': [{'type': 'Event', 'value': 'ë2'}, {'type': 'ThemRole', 'value': 'Theme'}, {'type': 'ThemRole', 'value': '?Trajectory'}]}, {'predicate_value': 'has_location', 'arguments': [{'type': 'Event', 'value': 'ë2'}, {'type': 'ThemRole', 'value': 'Theme'}, {'type': 'ThemRole', 'value': 'Source'}]}, {'predicate_value': 'has_location', 'arguments': [{'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Theme'}, {'type': 'ThemRole', 'value': 'Goal'}]}]}]
# ['escape-51.1-1-1', 'escape-51.1-1-2', 'escape-51.1-1-3']

# %% [markdown]
# # test 5
# This code comes from https://github.com/CognitiveHorizons/AMR-CSLogic/blob/rafactoring/amr_verbnet_semantics/test/test_predicate_kb.py The test data in the code comes from Rosario's code.
#
# This code doesn't work because it depends on the code I refactored. Please fix the importing part of this code.
#
# I have reported a bug related to this code 24 days ago. If that hasn't been fixed yet, please consider fixing this. All you need to do is to check if the return value is empty.
# > I added some test code. And I found one bug with amr_verbnet_semantics/test/test_query_semantics.py. In the following case, we do obtain an empty list. ground_amr method on amr_verbnet_enhance.py does not assume this result and thorws an error.

# %%
from amr_verbnet_semantics.service.verbnet import query_semantics
from amr_verbnet_semantics.service.semlink import query_pb_vn_mapping

queries = ["spray-9.7-2", "build-26.1-1", "stop-55.4-1-1"]
verbnet_version = 'verbnet3.4'
for q in queries:
    result = query_semantics(q, verbnet_version)
    print(f'query_semantics({q}) = {result}')


queries = ["admire.01", "enter.01", "possible.01", "green.02", "make_out.23", "admire-31_2"]
for q in queries:
    result = query_pb_vn_mapping(q)
    print(f'query_pb_vn_mapping({q}) = {result}')
# Out:
# query_semantics(spray-9.7-2) = {}
# query_semantics(build-26.1-1) = {('Asset', 'Agent', 'Product'): [{'predicate_value': 'be', 'arguments': [{'type': 'Event', 'value': 'e1'}, {'type': 'ThemRole', 'value': 'Product'}], 'is_negative': True}, {'predicate_value': 'do', 'arguments': [{'type': 'Event', 'value': 'e2'}, {'type': 'ThemRole', 'value': 'Agent'}], 'is_negative': False}, {'predicate_value': 'be', 'arguments': [{'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Product'}], 'is_negative': False}, {'predicate_value': 'made_of', 'arguments': [{'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Product'}, {'type': 'ThemRole', 'value': '?Material'}], 'is_negative': False}, {'predicate_value': 'cause', 'arguments': [{'type': 'Event', 'value': 'e2'}, {'type': 'Event', 'value': 'e3'}], 'is_negative': False}, {'predicate_value': 'cost', 'arguments': [{'type': 'Event', 'value': 'E'}, {'type': 'ThemRole', 'value': 'Product'}, {'type': 'ThemRole', 'value': 'Asset'}], 'is_negative': False}], ('Asset', 'Agent', 'Beneficiary', 'Product'): [{'predicate_value': 'be', 'arguments': [{'type': 'ThemRole', 'value': 'Product'}, {'type': 'Event', 'value': 'e1'}], 'is_negative': True}, {'predicate_value': 'do', 'arguments': [{'type': 'Event', 'value': 'e2'}, {'type': 'ThemRole', 'value': 'Agent'}], 'is_negative': False}, {'predicate_value': 'be', 'arguments': [{'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Product'}], 'is_negative': False}, {'predicate_value': 'made_of', 'arguments': [{'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Product'}, {'type': 'ThemRole', 'value': '?Material'}], 'is_negative': False}, {'predicate_value': 'cause', 'arguments': [{'type': 'Event', 'value': 'e2'}, {'type': 'Event', 'value': 'e3'}], 'is_negative': False}, {'predicate_value': 'benefit', 'arguments': [{'type': 'Event', 'value': 'E'}, {'type': 'ThemRole', 'value': 'Beneficiary'}], 'is_negative': False}, {'predicate_value': 'cost', 'arguments': [{'type': 'Event', 'value': 'E'}, {'type': 'ThemRole', 'value': 'Product'}, {'type': 'ThemRole', 'value': 'Asset'}], 'is_negative': False}], ('Material', 'Agent', 'Asset', 'Product'): [{'predicate_value': 'be', 'arguments': [{'type': 'ThemRole', 'value': 'Product'}, {'type': 'Event', 'value': 'e1'}], 'is_negative': True}, {'predicate_value': 'do', 'arguments': [{'type': 'Event', 'value': 'e2'}, {'type': 'ThemRole', 'value': 'Agent'}], 'is_negative': False}, {'predicate_value': 'be', 'arguments': [{'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Product'}], 'is_negative': False}, {'predicate_value': 'made_of', 'arguments': [{'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Product'}, {'type': 'ThemRole', 'value': 'Material'}], 'is_negative': False}, {'predicate_value': 'cause', 'arguments': [{'type': 'Event', 'value': 'e2'}, {'type': 'Event', 'value': 'e3'}], 'is_negative': False}, {'predicate_value': 'cost', 'arguments': [{'type': 'Event', 'value': 'E'}, {'type': 'ThemRole', 'value': 'Product'}, {'type': 'ThemRole', 'value': 'Asset'}], 'is_negative': False}], ('Asset', 'Agent', 'Material', 'Beneficiary', 'Product'): [{'predicate_value': 'be', 'arguments': [{'type': 'ThemRole', 'value': 'Product'}, {'type': 'Event', 'value': 'e1'}], 'is_negative': True}, {'predicate_value': 'do', 'arguments': [{'type': 'ThemRole', 'value': 'Agent'}, {'type': 'Event', 'value': 'e2'}], 'is_negative': False}, {'predicate_value': 'be', 'arguments': [{'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Product'}], 'is_negative': False}, {'predicate_value': 'made_of', 'arguments': [{'type': 'ThemRole', 'value': 'Material'}, {'type': 'Event', 'value': 'e3'}, {'type': 'ThemRole', 'value': 'Product'}], 'is_negative': False}, {'predicate_value': 'cause', 'arguments': [{'type': 'Event', 'value': 'e2'}, {'type': 'Event', 'value': 'e3'}], 'is_negative': False}, {'predicate_value': 'benefit', 'arguments': [{'type': 'ThemRole', 'value': 'Beneficiary'}, {'type': 'Event', 'value': 'E'}], 'is_ ...
# query_semantics(stop-55.4-1-1) = {('Theme', 'Agent'): [{'predicate_value': 'do', 'arguments': [{'type': 'Event', 'value': 'e1'}, {'type': 'ThemRole', 'value': 'Agent'}], 'is_negative': False}, {'predicate_value': 'cause', 'arguments': [{'type': 'Event', 'value': 'e2'}, {'type': 'Event', 'value': 'e1'}], 'is_negative': False}, {'predicate_value': 'end', 'arguments': [{'type': 'Event', 'value': 'E'}, {'type': 'ThemRole', 'value': 'Theme'}], 'is_negative': False}]}
# query_pb_vn_mapping(admire.01) = [{'mapping': 'admire-31.2', 'source': 'verbnet3.4'}]
# query_pb_vn_mapping(enter.01) = [{'mapping': 'escape-51.1-2', 'source': 'verbnet3.4'}]
# query_pb_vn_mapping(possible.01) = None
# query_pb_vn_mapping(green.02) = None
# query_pb_vn_mapping(make_out.23) = None
# query_pb_vn_mapping(admire-31_2) = None

# %% [markdown]
# # test 6
#
# Please check three sentences written in the [issue](https://github.com/CognitiveHorizons/AMR-CSLogic/issues/1). Are their return values the same with your assumptions?
#
# > (1) For observation text like "You can make out a green shirt" and "There isn't a thing there except a fridge" the output for 'grounded_stmt' is blank.
#     Answer: There are no groundings returned because propbank does not provide the semantic role mappings to verbnet for the frames possible.01, make-out.23, and green.02 for the first sentence, and except.01 for the second.
#
# > (2) For obs: "You are carrying a blue shoe, a green shirt", the verbnet predicates failed to bind to the groundings.
# Grounded smt: {'carry.01': {'carry-11.4': [[{'arguments': ['e1', 'y', '?Initial_Location'], 'is_negative': False, 'predicate': 'HAS_LOCATION'}, {'arguments': ['e2', 'y', '?Initial_Location'], 'is_negative': False, 'predicate': 'HAS_LOCATION'}, {'arguments': ['e3', 'y'], 'is_negative': False, 'predicate': 'DO'}, {'arguments': ['ë4', 'y', 'Trajectory'], 'is_negative': False, 'predicate': 'MOTION'}, {'arguments': ['ë4', 'y', '?Initial_Location'], 'is_negative': True, 'predicate': 'HAS_LOCATION'}, {'arguments': ['ë5', 'y', 'Trajectory'], 'is_negative': False, 'predicate': 'MOTION'}, {'arguments': ['ë5', 'y', '?Initial_Location'], 'is_negative': True, 'predicate': 'HAS_LOCATION'}, {'arguments': ['e6', 'y', '?Destination'], 'is_negative': False, 'predicate': 'HAS_LOCATION'}, {'arguments': ['e7', 'y', '?Destination'], 'is_negative': False, 'predicate': 'HAS_LOCATION'}, {'arguments': ['e3', 'ë4'], 'is_negative': False, 'predicate': 'CAUSE'}, {'arguments': ['ë4', 'ë5'], 'is_negative': False, 'predicate': 'CO-TEMPORAL'}]], 'cost-54.2': [[{'arguments': ['E', 'y', 's'], 'is_negative': False, 'predicate': 'HAS_VAL'}, {'arguments': ['E', 'y', 's2'], 'is_negative': False, 'predicate': 'HAS_VAL'}]], 'fit-54.3': [[{'arguments': ['E', 'y', 's'], 'is_negative': False, 'predicate': 'CAPACITY'}, {'arguments': ['E', 'y', 's2'], 'is_negative': False, 'predicate': 'CAPACITY'}]]}}
#
#     Answer: it is normal to have some arguments of the semantic ungrounded.

# %%
import time

from amr_verbnet_semantics.core.amr_verbnet_enhance import ground_text_to_verbnet

start = time.time()

text="You are carrying a blue shoe, a green shirt."
ret = ground_text_to_verbnet(text, use_coreference=False)
print(f"ret: {ret}")
print(f"\ngrounded_stmt_str: {ret['sentence_parses'][0]['grounded_stmt_str']}")
print(f"\nunique_grounded_stmt_str: {ret['sentence_parses'][0]['unique_grounded_stmt_str']}")

print(f'\nfinish with {time.time()-start:.3f} seconds')
# Out:
# amr:
#
# # ::tok You are carrying a blue shoe , a green shirt . <ROOT>
# # ::node	1	you	0-1
# # ::node	2	and	1-2
# # ::node	3	carry-01	2-3
# # ::node	4	blue	4-5
# # ::node	5	shoe	5-6
# # ::node	6	green-02	8-9
# # ::node	7	shirt	9-10
# # ::root	3	carry-01
# # ::edge	carry-01	ARG1	and	3	2
# # ::edge	carry-01	ARG0	you	3	1
# # ::edge	shoe	mod	blue	5	4
# # ::edge	and	op1	shoe	2	5
# # ::edge	shirt	ARG1-of	green-02	7	6
# # ::edge	and	op2	shirt	2	7
# # ::short	{1: 'y', 2: 'a', 3: 'c', 4: 'b', 5: 's', 6: 'g', 7: 's2'}
# (c / carry-01
#       :ARG0 (y / you)
#       :ARG1 (a / and
#             :op1 (s / shoe
#                   :mod (b / blue))
#             :op2 (s2 / shirt
#                   :ARG1-of (g / green-02))))
#
#
# ret: {'coreference': [], 'sentence_parses': [{'text': 'You are carrying a blue shoe, a green shirt.', 'amr': "# ::tok You are carrying a blue shoe , a green shirt . <ROOT>\n# ::node\t1\tyou\t0-1\n# ::node\t2\tand\t1-2\n# ::node\t3\tcarry-01\t2-3\n# ::node\t4\tblue\t4-5\n# ::node\t5\tshoe\t5-6\n# ::node\t6\tgreen-02\t8-9\n# ::node\t7\tshirt\t9-10\n# ::root\t3\tcarry-01\n# ::edge\tcarry-01\tARG1\tand\t3\t2\t\n# ::edge\tcarry-01\tARG0\tyou\t3\t1\t\n# ::edge\tshoe\tmod\tblue\t5\t4\t\n# ::edge\tand\top1\tshoe\t2\t5\t\n# ::edge\tshirt\tARG1-of\tgreen-02\t7\t6\t\n# ::edge\tand\top2\tshirt\t2\t7\t\n# ::short\t{1: 'y', 2: 'a', 3: 'c', 4: 'b', 5: 's', 6: 'g', 7: 's2'}\t\n(c / carry-01\n      :ARG0 (y / you)\n      :ARG1 (a / and\n            :op1 (s / shoe\n                  :mod (b / blue))\n            :op2 (s2 / shirt\n                  :ARG1-of (g / green-02))))\n\n", 'pb_vn_mappings': {'carry.01': [{'mapping': 'fit-54.3', 'source': 'verbnet3.4'}, {'mapping': 'cost-54.2', 'source': 'verbnet3.4'}, {'mapping': 'carry-11.4', 'source': 'verbnet3.4'}]}, 'role_mappings': {'carry.01': {'ARG0': [{'vncls': '11.4', 'vntheta': 'agent', 'description': 'carrier'}, {'vncls': '54.2', 'vntheta': 'theme', 'description': 'carrier'}, {'vncls': '54.3', 'vntheta': 'location', 'description': 'carrier'}], 'ARG1': [{'vncls': '11.4', 'vntheta': 'theme', 'description': 'thing carried'}, {'vncls': '54.2', 'vntheta': 'value', 'description': 'thing carried'}, {'vncls': '54.3', 'vntheta': 'value', 'description': 'thing carried'}], 'ARG4': [{'vncls': '54.2', 'vntheta': 'beneficiary', 'description': 'benefactive (predicted but not seen)'}]}, 'green.02': {}}, 'amr_cal': [{'predicate': 'carry-01', 'arguments': ['c'], 'is_negative': False}, {'predicate': 'you', 'arguments': ['y'], 'is_negative': False}, {'predicate': 'shoe', 'arguments': ['s'], 'is_negative': False}, {'predicate': 'blue', 'arguments': ['b'], 'is_negative': False}, {'predicate': 'shirt', 'arguments': ['s2'], 'is_negative': False}, {'predicate': 'green-02', 'arguments': ['g'], 'is_negative': False}, {'predicate': 'carry-01.arg0', 'arguments': ['c', 'y'], 'is_negative': False}, {'predicate': 'carry-01.arg1', 'arguments': ['c', 's'], 'is_negative': False}, {'predicate': 'mod', 'arguments': ['s', 'b'], 'is_negative': False}, {'predicate': 'green-02.arg1', 'arguments': ['g', 's2'], 'is_negative': False}, {'predicate': 'carry-01.arg1', 'arguments': ['c', 's2'], 'is_negative': False}], 'sem_cal': {'carry.01': {'fit-54.3': [{'predicate': 'CAPACITY', 'arguments': ['E', 'Location', 'Value'], 'is_negative': False}], 'cost-54.2': [{'predicate': 'HAS_VAL', 'arguments': ['E', 'Theme', 'Value'], 'is_negative': False}], 'carry-11.4': [{'predicate': 'HAS_LOCATION', 'arguments': ['e1', 'Theme', '?Initial_Location'], 'is_negative': False}, {'predicate': 'CAUSE', 'arguments': ['e3', 'ë4'], 'is_negative': False}, {'predicate': 'CO-TEMPORAL', 'arguments': ['ë4', 'ë5'], 'is_negative': False}, {'predicate': 'HAS_LOCATION', 'arguments': ['e2', 'Agent', '?Initial_Location'], 'is_negative': False}, {'predicate': 'DO', 'arguments': ['e3', 'Agent'], 'is_negative': False}, {'predicate': 'MOTION', 'arguments': ['ë4', 'Theme', 'Trajectory'], 'is_negative': False}, {'predicate': 'HAS_LOCATION', 'arguments': ['ë4', 'Theme', '?Initial_Location'], 'is_negative': True}, {'predicate': 'MOTION', 'arguments': ['ë5', 'Agent', 'Trajectory'], 'is_negative': False}, {'predicate': 'HAS_LOCATION', 'arguments': ['ë5', 'Agent', '?Initial_Location'], 'is_negative': True}, {'predicate': 'HAS_LOCATION', 'arguments': ['e6', 'Theme', '?Destination'], 'is_negative': False}, {'predicate': 'HAS_LOCATION', 'arguments': ['e7', 'Agent', '?Destination'], 'is_negative': False}]}}, 'unique_sem_cal': [{'carry.01': [{'predicate': 'CAPACITY', 'arguments': ['E', 'Location', 'Value'], 'is_negative': False}]}, {'carry.01': [{'predicate': 'HAS_VAL', 'arguments': ['E', 'Theme', 'Value'], 'is_negative': False}]}, {'carry.01': [{'predicate': 'HAS_LOCATION', 'arguments': [ ...
#
# grounded_stmt_str: {'carry.01': {'fit-54.3': [[CAPACITY(E, y, s), CAPACITY(E, y, s2)]], 'cost-54.2': [[HAS_VAL(E, y, s), HAS_VAL(E, y, s2)]], 'carry-11.4': [[HAS_LOCATION(e1, y, ?Initial_Location), CAUSE(e3, ë4), CO-TEMPORAL(ë4, ë5), HAS_LOCATION(e2, y, ?Initial_Location), DO(e3, y), MOTION(ë4, y, Trajectory), NOT(HAS_LOCATION(ë4, y, ?Initial_Location)), MOTION(ë5, y, Trajectory), NOT(HAS_LOCATION(ë5, y, ?Initial_Location)), HAS_LOCATION(e6, y, ?Destination), HAS_LOCATION(e7, y, ?Destination)]]}}
#
# unique_grounded_stmt_str: [{'carry.01': [[CAPACITY(E, y, s), CAPACITY(E, y, s2)]]}, {'carry.01': [[HAS_VAL(E, y, s), HAS_VAL(E, y, s2)]]}, {'carry.01': [[HAS_LOCATION(e1, y, ?Initial_Location), CAUSE(e3, ë4), CO-TEMPORAL(ë4, ë5), HAS_LOCATION(e2, y, ?Initial_Location), DO(e3, y), MOTION(ë4, y, Trajectory), NOT(HAS_LOCATION(ë4, y, ?Initial_Location)), MOTION(ë5, y, Trajectory), NOT(HAS_LOCATION(ë5, y, ?Initial_Location)), HAS_LOCATION(e6, y, ?Destination), HAS_LOCATION(e7, y, ?Destination)]]}]
#
# finish with 1.656 seconds
